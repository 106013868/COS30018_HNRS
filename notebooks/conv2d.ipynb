# %%
import sys
sys.path.append("..")

from hnrs.preprocessing import load_preprocessed_mnist

x_train, y_train, y_cat_train, x_test, y_test, y_cat_test = load_preprocessed_mnist()

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import keras
from keras import Input
from keras.models import Sequential
from keras.layers import Dense, Dropout, Reshape, Flatten, MaxPooling2D, Conv2D
from sklearn.metrics import confusion_matrix

# %%
keras.utils.set_random_seed(42)
model = Sequential()

model.add(Input(shape=(28, 28)))
model.add(Reshape((28, 28, 1)))
model.add(Conv2D(32, 3, activation="relu"))
model.add(MaxPooling2D())
model.add(Conv2D(64, 3, activation="relu"))
model.add(MaxPooling2D())
model.add(Flatten())
model.add(Dense(128, activation="relu"))
model.add(Dropout(0.2))
model.add(Dense(10, activation="softmax"))
model.compile(loss="categorical_crossentropy", optimizer="adam", metrics=["accuracy"])
model.summary()
# Out:
# Model: "sequential_7"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ reshape_7 (Reshape)             │ (None, 28, 28, 1)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_14 (Conv2D)              │ (None, 26, 26, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_14 (MaxPooling2D) │ (None, 13, 13, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_15 (Conv2D)              │ (None, 11, 11, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_15 (MaxPooling2D) │ (None, 5, 5, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_7 (Flatten)             │ (None, 1600)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_14 (Dense)                │ (None, 128)            │       204,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_7 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_15 (Dense)                │ (None, 10)             │         1,290 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 225,034 (879.04 KB)
#  Trainable params: 225,034 (879.04 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
batch_size = 256
epochs = 10
model.fit(x=x_train, y=y_cat_train, batch_size=batch_size, epochs=epochs, validation_split=0.2)
# Out:
# Epoch 1/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 10s 45ms/step - accuracy: 0.8970 - loss: 0.3601 - val_accuracy: 0.9722 - val_loss: 0.0922
# Epoch 2/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 8s 43ms/step - accuracy: 0.9721 - loss: 0.0912 - val_accuracy: 0.9831 - val_loss: 0.0642
# Epoch 3/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 8s 42ms/step - accuracy: 0.9799 - loss: 0.0647 - val_accuracy: 0.9868 - val_loss: 0.0518
# Epoch 4/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 9s 48ms/step - accuracy: 0.9850 - loss: 0.0489 - val_accuracy: 0.9873 - val_loss: 0.0476
# Epoch 5/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 9s 47ms/step - accuracy: 0.9879 - loss: 0.0390 - val_accuracy: 0.9877 - val_loss: 0.0432
# Epoch 6/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 8s 45ms/step - accuracy: 0.9904 - loss: 0.0327 - val_accuracy: 0.9894 - val_loss: 0.0398
# Epoch 7/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 9s 50ms/step - accuracy: 0.9912 - loss: 0.0286 - val_accuracy: 0.9892 - val_loss: 0.0403
# Epoch 8/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 9s 48ms/step - accuracy: 0.9927 - loss: 0.0239 - val_accuracy: 0.9886 - val_loss: 0.0408
# Epoch 9/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 9s 48ms/step - accuracy: 0.9932 - loss: 0.0211 - val_accuracy: 0.9901 - val_loss: 0.0383
# Epoch 10/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 9s 48ms/step - accuracy: 0.9939 - loss: 0.0192 - val_accuracy: 0.9897 - val_loss: 0.0389

# %%
test_loss, test_acc = model.evaluate(x_test, y_cat_test)
print("Test Loss: {}, Test Accuracy: {}".format(test_loss, test_acc))
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9900 - loss: 0.0321
# Test Loss: 0.03212762624025345, Test Accuracy: 0.9900000095367432

# %%
y_pred = model.predict(x_test).argmax(axis=1)
print(confusion_matrix(y_test, y_pred))
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# [[ 976    1    0    0    0    0    0    2    1    0]
#  [   0 1132    1    1    0    0    1    0    0    0]
#  [   0    1 1021    0    1    0    0    6    3    0]
#  [   0    0    1 1004    0    2    0    1    2    0]
#  [   0    2    1    0  971    0    1    0    0    7]
#  [   2    0    1    8    0  877    1    1    0    2]
#  [   3    3    1    0    1    4  942    0    4    0]
#  [   0    3    1    1    0    0    0 1021    0    2]
#  [   2    0    2    1    0    0    0    2  962    5]
#  [   1    3    0    0    5    2    0    2    2  994]]

# %%
model.save("../models/con2d.keras")
